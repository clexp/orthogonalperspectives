# %% [markdown]
# <a href="https://colab.research.google.com/github/clexp/journey_to_ML/blob/main/my_first_colab_from_scratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello world!")
# Out:
# hello world!

# %% [markdown]
# Welcom to the **HMSA** prowgramme?!!

# %% [markdown]
# # this is a section heading

# %% [markdown]
# this is all the text in this section

# %%
print("and this is code in the section")

# %% [markdown]
# # and this is a new section

# %% [markdown]
# to test the 'hidden' section function

# %%
import matplotlib.pyplot as plt
from random import randint as rnd
x = [  rnd(50,400) for _ in range (60)]
y = [ 2*_ + (rnd(-5,5)/5)*_ for _ in x]
plt.scatter(x,y)
plt.xlabel('jumbos')
plt.ylabel('mumbos')
plt.title('mumbos verses jumbos')
plt.show()
